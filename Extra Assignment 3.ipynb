# %%
pwd='HopeAI@123'
env = input('please enter the password')
if env == pwd:
    print('password is correct')
else:
    print('password is incorrect')
# Out:
# please enter the password HopeAI@123
# password is correct

# %%
age = int(input('please enter the age'))
if age < 18:
    print('children')
elif age < 60:
    print('adult')
else:
    print('senior citizen')
# Out:
# please enter the age 45
# adult

# %%
v = int(input('please enter the value'))
if v >= 0:
    print('Positive')
else:
    print('Negative')
# Out:
# please enter the value -9
# Negative

# %%
v = int(input('please enter the value'))
if (v%5)== 0:
    print('divisible by 5')
else:
    print('Not divisible by 5')
# Out:
# please enter the value 20
# divisible by 5

# %%
s = """welcome to Pyhton"""
print(s)
s = """welcome 
to Pyhton"""
print(s)
#""" is for multiline string
# Out:
# welcome to Pyhton
# welcome
# to Pyhton

# %%
print("jagan " * 3)
# string repetition
# Out:
# jagan jagan jagan

# %%
p="python programming"
print(p.capitalize())
print(p.title())
p.capitalize()
p.title()
# Out:
# Python programming
# Python Programming
# 'Python Programming'

# %%
#trim spaee
s=" jk si_"
print(s)
print(s.strip("_"))
print(s.lstrip())
print(s.rstrip())
# Out:
#  jk si_
#  jk si
# jk si_
#  jk si_

# %%
s="jagan"
s.find('a')
len(s)
s.count('a')
# Out:
# 2

# %%
s='jagan_Nathan'
s.split('_')
s='jagan Nathan'
s.isspace()
# Out:
# False

# %%
L=[10,20,30]
print(L)
L.append(38)
print(L)
L.remove(20)
print(L)
L[2]=39
print(L)
x=L.pop(2);
print(L)
y=L.pop()
print(L)
L.clear()
print(L)
print(x)
print(y)
# Out:
# [10, 20, 30]
# [10, 20, 30, 38]
# [10, 30, 38]
# [10, 30, 39]
# [10, 30]
# [10]
# []
# 39
# 30

# %%
L=[20,10,30,40]
y=L

print(L)
L.sort(reverse=True)
print(L)
print(y)
# Out:
# [20, 10, 30, 40]
# [40, 30, 20, 10]
# [40, 30, 20, 10]

# %%
L.index(40)
# Out:
# 0

# %%
L=int(input('enter values'))
print(L)
print(type(L))
L=list(map(int,input('enter values').split()))
print(L)
print(type(L))
# Out:
# enter values 10
# 10
# <class 'int'>
# enter values 10 20 30
# [10, 20, 30]
# <class 'list'>

# %%
#Tuple
#person = ("Jagan", 30, "India")
person = "Jagan", 30, "India" # we can assign with out paranthesis

name, age, country = person

print(name)
print(age)
print(country)
# Out:
# Jagan
# 30
# India

# %%
#set
s={10,20,30,50,40,10,10}
print(s);
s.add(30)
print(s);
s.remove(30)
print(s);
s.discard(40)
print(s);
p={70,80,10}
print(p);
print(s|p) # union
print(s&p) # intersect
print(s-p) # difference
print(p-s) # difference
# Out:
# {50, 20, 40, 10, 30}
# {50, 20, 40, 10, 30}
# {50, 20, 40, 10}
# {50, 20, 10}
# {80, 10, 70}
# {80, 50, 20, 70, 10}
# {10}
# {50, 20}
# {80, 70}

# %%
conversation_detail =     {
      "conversationEnd": "2024-09-25T19:02:31.289Z",
      "conversationId": "3a956419",
      "conversationStart": "2024-09-25T18:31:56.337Z",
      "divisionIds": [
        "01,02"
      ],
      "mediaStatsMinConversationMos": 4.374929475980374,
      "mediaStatsMinConversationRFactor": 79.43991088867188,
      "originatingDirection": "inbound"
}
print(conversation_detail)
print(conversation_detail["conversationId"])
print(conversation_detail.get("conversation_Id",123)) # set default value if key is not avl
conversation_detail.keys()
conversation_detail.values()
# Out:
# {'conversationEnd': '2024-09-25T19:02:31.289Z', 'conversationId': '3a956419', 'conversationStart': '2024-09-25T18:31:56.337Z', 'divisionIds': ['01,02'], 'mediaStatsMinConversationMos': 4.374929475980374, 'mediaStatsMinConversationRFactor': 79.43991088867188, 'originatingDirection': 'inbound'}
# 3a956419
# 123
# dict_values(['2024-09-25T19:02:31.289Z', '3a956419', '2024-09-25T18:31:56.337Z', ['01,02'], 4.374929475980374, 79.43991088867188, 'inbound'])

# %%
print(conversation_detail.items())
print(conversation_detail)
print("____________________")
print(conversation_detail["conversationEnd"])
print(conversation_detail.get("conversatonEnd"))
#add attributes with values
conversation_detail["comment"]="testing"
#update
conversation_detail.update({
    "divisionname":"Home",
    "username":"jagan"
})
print(conversation_detail)
# Out:
# dict_items([('conversationEnd', '2024-09-25T19:02:31.289Z'), ('conversationId', '3a956419'), ('conversationStart', '2024-09-25T18:31:56.337Z'), ('divisionIds', ['01,02']), ('mediaStatsMinConversationMos', 4.374929475980374), ('mediaStatsMinConversationRFactor', 79.43991088867188), ('originatingDirection', 'inbound')])
# {'conversationEnd': '2024-09-25T19:02:31.289Z', 'conversationId': '3a956419', 'conversationStart': '2024-09-25T18:31:56.337Z', 'divisionIds': ['01,02'], 'mediaStatsMinConversationMos': 4.374929475980374, 'mediaStatsMinConversationRFactor': 79.43991088867188, 'originatingDirection': 'inbound'}
# ____________________
# 2024-09-25T19:02:31.289Z
# None
# ...

# %%
#Play tuple
T=(10,)
print(type(T))
T=("anna nagar",35)
area,door_no = T
print(T)
print(area,door_no)
# Out:
# <class 'tuple'>
# ('anna nagar', 35)
# anna nagar 35

# %%
#Play set
a={}
print(type(a))
a={10,20}
print(type(a))

a=set() #how do define empty set
print(type(a))
a={10,20,30}
b={30,40,50}
print(a.union(b))
print(a|b)
print(a.intersection(b))
print(a&b)
print(a.difference(b))
print(a-b)
print(a.symmetric_difference(b))
print(a^b)
a.add(70);
print(a)
a.update([70,80])
print(a)
a.discard(80);
print(a)
a.difference_update([80,70])
a.difference_update([80])
print(a)
a.clear()
print(a)
# Out:
# <class 'dict'>
# <class 'set'>
# <class 'set'>
# {50, 20, 40, 10, 30}
# {50, 20, 40, 10, 30}
# {30}
# {30}
# {10, 20}
# {10, 20}
# {40, 10, 50, 20}
# {40, 10, 50, 20}
# {70, 10, 20, 30}
# {70, 10, 80, 20, 30}
# {70, 10, 20, 30}
# {10, 20, 30}
# set()

# %%
#dict exercise
name="Jaganathan"
outp={}
print(type(outp))
for x in name:
    if x in outp:
        outp[x]+=1
    else:
        outp[x]=1
print(outp)
for key,value in outp.items():
    print(key,value)
y=0
k=''
for key,value in outp.items():
    
    if y < value:
        y=value
        k=key
print("key contains max value:",k)
# Out:
# <class 'dict'>
# {'J': 1, 'a': 4, 'g': 1, 'n': 2, 't': 1, 'h': 1}
# J 1
# a 4
# g 1
# n 2
# t 1
# h 1
# key contains max value: a
